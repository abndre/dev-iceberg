# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("pokemon2").getOrCreate()
# Out:
# 24/10/23 11:22:18 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
df = spark.table("pokemon.primeira_geracao")

# %%
df.show()
# Out:
# +------+----------+------+------+-------+
# |numero|      name|ataque|defesa|energia|
# +------+----------+------+------+-------+
# |    30|  nidorina|    62|    67|     70|
# |   105|   marowak|    80|   110|     60|
# |    64|   kadabra|    35|    30|     40|
# |   120|    staryu|    45|    55|     30|
# |    52|    meowth|    45|    35|     40|
# |     8| wartortle|    63|    80|     59|
# |    66|    machop|    80|    50|     70|
# |    92|    gastly|    35|    30|     30|
# |    60|   poliwag|    50|    40|     40|
# |    74|   geodude|    80|   100|     40|
# |    98|    krabby|   105|    90|     30|
# |    75|  graveler|    95|   115|     55|
# |    71|victreebel|   105|    65|     80|
# |    72| tentacool|    40|    35|     40|
# |    25|   pikachu|    55|    40|     35|
# |    73|tentacruel|    70|    65|     80|
# |   140|    kabuto|    80|    90|     30|
# |    26|    raichu|    90|    55|     60|
# |    79|  slowpoke|    65|    65|     90|
# ...

# %%
# %%sql
# SELECT * FROM pokemon.primeira_geracao order by numero;
# Out:
# +--------+------------+--------+--------+---------+
# | numero |       name | ataque | defesa | energia |
# +--------+------------+--------+--------+---------+
# |      1 |  bulbasaur |     49 |     49 |      45 |
# |      2 |    ivysaur |     62 |     63 |      60 |
# |      3 |   venusaur |     82 |     83 |      80 |
# |      4 | charmander |     52 |     43 |      39 |
# |      5 | charmeleon |     64 |     58 |      58 |
# |      6 |  charizard |     84 |     78 |      78 |
# |      7 |   squirtle |     48 |     65 |      44 |
# |      8 |  wartortle |     63 |     80 |      59 |
# |      9 |  blastoise |     83 |    100 |      79 |
# |     10 |   caterpie |     30 |     35 |      45 |
# |     11 |    metapod |     20 |     55 |      50 |
# |     12 | butterfree |     45 |     50 |      60 |
# |     13 |     weedle |     35 |     30 |      40 |
# |     14 |     kakuna |     25 |     50 |      45 |
# |     15 |   beedrill |     90 |     40 |      65 |
# ...
